# %% [markdown]
# בנק - בתרגיל הזה נכתוב מערכת קצת יותר חכמה לבנק. נבנה אותה בשלבים
#
# בשלב הראשון נבנה מחולל סיסמאות עבור משתמש. מחולל סיסמאות היא פונקציה שמקבלת שם משתמש ומחזירה סיסמה
# הסיסמה תורכב כך: שם המשתמש במהופך מחובר אליו "X" כאורך השם

# %%
#password_generator("stam") --> "matsXXXX"

# %% [markdown]
# בדקו את מחולל הסיסמאות שלכם עם 4 סיסמאות באורכים משתנים

# %% [markdown]
#  קלטו מהמשתמש שם משתמש וסיסמה, חשבו את הסיסמה עם הפונקציה שכתבתם והדפיסו ברוך הבא אם הסיסמא נכונה, אחרת הדפיסו סיסמא לא נכונה

# %% [markdown]
# כתבו פונקציה שמחזירה
# True
# אם בוצע חיבור מוצלח, אחרת החזירו False
#
# הפונקציה מקבלת שם משתמש וסיסמה. בודקת את נכונות הסיסמה ומחזירה
# True
# אם היא נכונה ו
# False
# אחרת
#
#  כעת כתבו את השאלה הקודמת באמצעות הפונקציה שכתבתם בסעיף זה

# %% [markdown]
# לכל משתמש יש בבנק 500 שח.
# כעת נרצה שהתוכנה שלנו תאפשר למשתמש למשוך כסף.
#
# נשתמש בפונקציות הקודמות שכתבנו:
#
# נקלוט מהמשתמש שם משתמש וסיסמא
# אם ההתחברות הצליחה
# נשאל אותו איזה סכום ירצה למשוך
#
# אם הסכום גדול מ-500:
# נדפיס "אין לך מספיק כסף"
#
# אם הסכום הוא 0 נדפיס "לא ניתן למשוך 0 שח"
#
# אם הסכום שלילי נכתוב "לא ניתן למשוך סכום שלילי"
#
# אם הסכום תקין, נדפיס:
# הנה הסכום שביקשת: X
# נשאר בחשבון:
# 500-X

# %% [markdown]
# ציירו תחילה על דף תרשים זרימה של איך הולך להיראות הקוד - תרשים מעויינים ללא קוד.
# זה יעזור במימוש

# %% [markdown]
# ממיר זמן:
# נכתוב פונקציה שמקבלת את השעה בשני ארגומנטים (שעה,דקות) ואיזור זמן מבין:
# תל אביב- TLV
# לונדון - LONDON
# ניו יורק ארה"ב - NY
# טוקיו - TOKYO
#
# אם נקבל תל אביב, נדפיס את השעה בתוספת 3 שעות (זכרו ששעון הוא מעגלי, כלומר אם השעה 23 ונבקש את השעה בישראל נחזיר 2)
#
# אם נקבל ניו יורק נחזיר את השעה פחות 4
#
# אם נקבל טוקיו נחזיר את השעה ועוד 9
#
# בכל מקרה אחרת נחזיר את השעה כמו שקיבלנו אותה

# %% [markdown]
# כתבו פונקציה שמקבלת 2 רשימות שונות
# מדפיסה
# "same length"
# אם הן באותו אורך.
# ואחרת
# "not same length"
#
# אם קיבלנו רשימה באורך 0 - תודפס
# "got empty list"
#
# אם קיבלנו 2 רשימות ריקות אז נדפיס
# "got empty list"
# "got empty list"
# "same length"

# %% [markdown]
# כעת אחרי שלמדנו על רשימות ועל האופרטור
# in
# נרצה לשכלל את הבנק שלנו
# לבנק שלנו יוכלו לגשת רק מס לקוחות מצומצם שיוגדר ברשימה
# הגדירו רשימה של שמות של לקוחות, שרק עבור לקוח מהרשימה יתאפשר החיבור, ועל כל לקוח אחר הבנק יכתוב
# "you are not customer of the bank"

# %% [markdown]
# נתאמן על
# indexing
#
# כתבו פונקציה שמקבלת רשימה של רשימות
# אם הרשימה לא באורך 6 הפונקציה תדפיס
# "only lists of length 6"
#
# הפונקציה תדפיס
# "yes!"
# אם:
#     אורך הרשימה במקום ה-0 שווה לאורך הרשימה במקום ה-4
#     או
#     אורך הרשימה במקום ה3 שווה לאורך הרשימה במקום ה-2 וה-1
#     או
#     אורך הרשימה במקום ה5 שווה ל-3
#
# אם כמה תנאים מתקיימים בו זמנית, הפונקציה תדפיס עבור כל תנאי שמתקיים
# (חשבו איך לכתוב את זה)
# לדוגמא עבור:
# multi = [[0],[1],[2],[3],[4],[5]]
# כל התנאים מתקיימים - נדפיס 3 פעמים
#
# כתבו לפחות 5 דוגמאות שונות שמדגימות:
# בלי הדפסות
# הדפסה אחת
# שתי הדפסות
# שלוש הדפסות

# %% [markdown]
# נתאמן על פעולות של מחרוזות
